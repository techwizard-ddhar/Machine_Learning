# %%
pip install pandas
# Out:
# ...
#                                               0.0/10.6 MB ? eta -:--:--
#                                               0.0/10.6 MB ? eta -:--:--
#                                              0.0/10.6 MB 435.7 kB/s eta 0:00:25
#                                              0.1/10.6 MB 465.5 kB/s eta 0:00:23
#                                              0.1/10.6 MB 726.2 kB/s eta 0:00:15
#                                              0.1/10.6 MB 554.9 kB/s eta 0:00:19
#                                              0.2/10.6 MB 573.4 kB/s eta 0:00:19
#                                              0.3/10.6 MB 827.5 kB/s eta 0:00:13
#      -                                       0.4/10.6 MB 995.6 kB/s eta 0:00:11
#      --                                       0.5/10.6 MB 1.4 MB/s eta 0:00:08
#      --                                       0.7/10.6 MB 1.6 MB/s eta 0:00:07
#      ---                                      0.8/10.6 MB 1.7 MB/s eta 0:00:06
# ...

# %%
import pandas as pd

# %% [markdown]
# CSV (Comma Separated Values) --> create a DataFrame, which is a two-dimensional tabular data structure, to store the data in a way that makes it easy to analyze and manipulate.

# %%
a = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
a
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
type(a)  # Data Frame
# Out:
# pandas.core.frame.DataFrame

# %%
df = a.copy()

# %% [markdown]
# This can be very useful when you want to perform different operations on the same dataset without modifying the original data

# %%
df.head() # by default it gives 5 values
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df.head(3)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa

# %%
df.shape
# Out:
# (149, 5)

# %%
df.dtypes
# Out:
# 5.1            float64
# 3.5            float64
# 1.4            float64
# 0.2            float64
# Iris-setosa     object
# dtype: object

# %%
df.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %%
df.columns = ["sepal-length", "sepal-width", "petal-length", "petal-width", "flower-type"] # change nammes of columns

# %%
df.columns
# Out:
# Index(['sepal-length', 'sepal-width', 'petal-length', 'petal-width',
#        'flower-type'],
#       dtype='object')

# %%
df.dtypes
# Out:
# sepal-length    float64
# sepal-width     float64
# petal-length    float64
# petal-width     float64
# flower-type      object
# dtype: object

# %%
df.head()
# Out:
#    sepal-length  sepal-width  petal-length  petal-width  flower-type
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
df.describe()
# Out:
#        sepal-length  sepal-width  petal-length  petal-width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.848322     3.051007      3.774497     1.205369
# std        0.828594     0.433499      1.759651     0.761292
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df["sepal-length"] # to check a particular column
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sepal-length, Length: 149, dtype: float64

# %%
df.isnull()  # to check if there is any null value
# Out:
#      sepal-length  sepal-width  petal-length  petal-width  flower-type
# 0           False        False         False        False        False
# 1           False        False         False        False        False
# 2           False        False         False        False        False
# 3           False        False         False        False        False
# 4           False        False         False        False        False
# ..            ...          ...           ...          ...          ...
# 144         False        False         False        False        False
# 145         False        False         False        False        False
# 146         False        False         False        False        False
# 147         False        False         False        False        False
# 148         False        False         False        False        False
#
# [149 rows x 5 columns]

# %%
df.isnull().sum()   # to find total null values
# Out:
# sepal-length    0
# sepal-width     0
# petal-length    0
# petal-width     0
# flower-type     0
# dtype: int64

# %%
df.iloc[50:61, 2:]     # Slice of data
# Out:
#     petal-length  petal-width      flower-type
# 50           4.5          1.5  Iris-versicolor
# 51           4.9          1.5  Iris-versicolor
# 52           4.0          1.3  Iris-versicolor
# 53           4.6          1.5  Iris-versicolor
# 54           4.5          1.3  Iris-versicolor
# 55           4.7          1.6  Iris-versicolor
# 56           3.3          1.0  Iris-versicolor
# 57           4.6          1.3  Iris-versicolor
# 58           3.9          1.4  Iris-versicolor
# 59           3.5          1.0  Iris-versicolor
# 60           4.2          1.5  Iris-versicolor
